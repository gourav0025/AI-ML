# %%
import os
new_dir = "package"
os.mkdir(new_dir)

# %%
# Getting the list of all folders and files in a directory
items = os.listdir("../")
print(items)

# %%
# Joinig paths to get relative path
folder_rel_path = "package"
file = "new_file.txt"

full_rel_path = os.path.join(folder_rel_path, file)

print(full_rel_path)
# Out:
# package/new_file.txt

# %%
## getting absolute path to the file
abs_file_path = os.path.abspath(full_rel_path)
abs_file_path
# Out:
# '/Users/gouravpanseja/AI_ML/h_file_paths/package/new_file.txt'

# %%
# To check if a file or Folder exists in current working dir
path="exp.txt"

if os.path.exists(path) :
    print(f"{path} is present")
else:
    with open(path, "x") : ...
    print("file created")
# Out:
# exp.txt is present

# %%
try:
    f = open("exp.txt", "r")

except FileNotFoundError as e:
    print(e)
except Exception as e:
    print(e)
finally:
    if (('f' in locals()) and not (f.closed)):
        f.close()
        print('file closed')
# Out:
# division by zero
