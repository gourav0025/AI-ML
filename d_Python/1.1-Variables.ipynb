# %%
l = [1,2,3,4]

print(l[1: ])
# Out:
# [2, 3, 4]

# %%
l2 = l[::-1];
print(l2);
# Out:
# [4, 3, 2, 1]

# %%
l3 = list(range(0,5))

# %%
t1 = (1,2,3);

t2 = (4,5,6);

t3 = t1+t2;

print(t3);
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
l1 = [1,2,3,4,5]

l2 = [i for i in l1]

a,b,*c = l2
print(a,b,c)
# Out:
# 1 2 [3, 4, 5]

# %%
t = (1,2,3,4,5,6)
a,*b,c = t

print(a,b,c)
type(b)
# Out:
# 1 [2, 3, 4, 5] 6
# list

# %%
s = {1}
type(s)
# Out:
# set

# %%
my_set = {1,2,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1 = {1,2,3,4}
s2 = {2,1,6,9}

s1.intersection_update(s2)

s1.issubset 

print(s1)
# Out:
# {1, 2}

# %%
d1 = {"name" : "gourav", "age" : 23}
d2 = d1.copy()

d2["age"] = 33

print(d1)
print(d2)
# Out:
# {'name': 'gourav', 'age': 23}
# {'name': 'rohan', 'age': 23}
